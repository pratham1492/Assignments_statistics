# %%
# Q1

import matplotlib.pyplot as plt

orders = [12, 15, 17, 14, 13, 16, 200, 18, 14, 15]

plt.plot(orders, marker="o")
plt.title("Swiggy Daily Orders")
plt.xlabel("Day")
plt.ylabel("Orders")
plt.grid(True)

# %%
# Q2

followers = [5, 7, 8, 8, 9, 10, 12, 15, 95]

mean = sum(followers) / len(followers)

followers.sort()
median = followers[len(followers)//2]

print("Mean =", round(mean,2))
print("Median =", median)
# Out:
# Mean = 18.78
# Median = 9

# %%
# Q4

import matplotlib.pyplot as plt

ratings = [3, 3, 4, 4, 4, 5, 5, 5, 5, 5]

plt.hist(ratings, bins=[2.5, 3.5, 4.5, 5.5], edgecolor="black")

plt.title("Flipkart Product Ratings")
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.xticks([3, 4, 5])
# Out:
# ([<matplotlib.axis.XTick at 0x13ec824da90>,
#   <matplotlib.axis.XTick at 0x13ec82842d0>,
#   <matplotlib.axis.XTick at 0x13ec8284a50>],
#  [Text(3, 0, '3'), Text(4, 0, '4'), Text(5, 0, '5')])
