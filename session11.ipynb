# %%
# Q1

playlist = [210, 180, 245, 200, 175]

print(sum(playlist))
# Out:
# 1010

# %%
# Q2

ratings = [
    [5, 4, 3],
    [4, 5, 2],
    [3, 4, 5]
]

print(ratings)

print(ratings[0][1])
print(ratings[1][1])
print(ratings[2][1])
# Out:
# [[5, 4, 3], [4, 5, 2], [3, 4, 5]]
# 4
# 5
# 4

# %%
# Q3

orders = [
    [10, 20, 15, 18],
    [12, 25, 14, 20],
    [15, 22, 18, 16]
]

print(orders[0][0] + orders[1][0] + orders[2][0])
print(orders[0][1] + orders[1][1] + orders[2][1])
print(orders[0][2] + orders[1][2] + orders[2][2])
print(orders[0][3] + orders[1][3] + orders[2][3])
# Out:
# 37
# 67
# 47
# 54

# %%
# Q4

products = [
    [500, 10],
    [800, 5],
    [1200, 3],
    [300, 20],
    [700, 8]
]

def revenue(data):
    for i in data:
        print(i[0] * i[1])

revenue(products)
# Out:
# 5000
# 4000
# 3600
# 6000
# 5600
