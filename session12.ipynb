# %%
# Q1

a = [
    [2, 3],
    [4, 5]
]

b = [
    [1, 2],
    [3, 4]
]

result = [
    [
        a[0][0] * b[0][0] + a[0][1] * b[1][0],
        a[0][0] * b[0][1] + a[0][1] * b[1][1]
    ],
    [
        a[1][0] * b[0][0] + a[1][1] * b[1][0],
        a[1][0] * b[0][1] + a[1][1] * b[1][1]
    ]
]

print(result)
# Out:
# [[11, 16], [19, 28]]

# %%
# Q2

def linear_regression_predict(x, m, c):
    return m * x + c

print(linear_regression_predict(5, 4, 10))
# Out:
# 30

# %%
# Q3

def linear_regression_predict(x, m, c):
    return m * x + c

print(linear_regression_predict(2, 4, 10))
print(linear_regression_predict(5, 4, 10))
print(linear_regression_predict(8, 4, 10))
# Out:
# 18
# 30
# 42

# %%
# Q4

# Slope: Slope shows how much the price changes when the product rating increases by 1. A higher slope means the price increases more.

# Intercept:
# Intercept is the starting price when the rating is 0. It is the base value used by the model.

# %%
# Q5

# Matrix multiplication helps compare users and songs quickly. It finds songs that match a user's taste. This makes Spotify give better and faster song recommendations.
