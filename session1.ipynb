# %%
# Q1

import pandas as pd

data = {
    "Daily Action": [
        "Instagram Likes",
        "Instagram Comment",
        "Zomato Rating",
        "Flipkart Product Category",
        "Flipkart Order Amount"
    ],
    "Data Type": [
        "Numerical",
        "Categorical",
        "Numerical",
        "Categorical",
        "Numerical"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                 Daily Action    Data Type
# 0            Instagram Likes    Numerical
# 1          Instagram Comment  Categorical
# 2              Zomato Rating    Numerical
# 3  Flipkart Product Category  Categorical
# 4      Flipkart Order Amount    Numerical

# %%
# Q2

music = ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop']

print("Data:", music)
print("\nType of Data: Categorical")

print("""
Reason:
The values are music genres.
They are names (labels), not numbers, so this is categorical data.
""")
# Out:
# Data: ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop']
#
# Type of Data: Categorical
#
# Reason:
# The values are music genres.
# They are names (labels), not numbers, so this is categorical data.

# %%
# Q3

feature = "Instagram Likes"

print("Feature:", feature)

print("""
Statistics can help find the average number of likes on posts.
It can recommend popular posts to users based on engagement.
""")
# Out:
# Feature: Instagram Likes
#
# Statistics can help find the average number of likes on posts.
# It can recommend popular posts to users based on engagement.

# %%
# Q4

terms = {
    "Mean": "Average songs listened per day. Example: 40 songs/day.",
    "Median": "Middle value of daily listening time. Example: 60 minutes.",
    "Mode": "Most frequently played genre. Example: Pop."
}

df = pd.DataFrame(terms.items(), columns=["Statistical Term", "Example"])
df
# Out:
#   Statistical Term                                            Example
# 0             Mean  Average songs listened per day. Example: 40 so...
# 1           Median  Middle value of daily listening time. Example:...
# 2             Mode        Most frequently played genre. Example: Pop.
