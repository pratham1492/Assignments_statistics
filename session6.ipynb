# %%
# Q1

print("H0 : People do not spend more time on Instagram than YouTube.")
print("H1 : People spend more time on Instagram than YouTube.")
# Out:
# H0 : People do not spend more time on Instagram than YouTube.
# H1 : People spend more time on Instagram than YouTube.

# %%
# Q2

from scipy.stats import ttest_ind_from_stats

a = 350
b = 320
sd = 50
n = 30

t, p = ttest_ind_from_stats(a, sd, n, b, sd, n)

print("T Value =", t)
print("P Value =", p)

if p < 0.05:
    print("Reject H0")
else:
    print("Accept H0")
# Out:
# T Value = 2.32379000772445
# P Value = 0.023662215835435832
# Reject H0

# %%
# Q3

print("App : WhatsApp")

print("Control Group : Old Dark Mode")
print("Variant Group : New Dark Mode")

print("Metric : Time Spent")

print("H0 : New design does not increase usage.")
print("H1 : New design increases usage.")
# Out:
# App : WhatsApp
# Control Group : Old Dark Mode
# Variant Group : New Dark Mode
# Metric : Time Spent
# H0 : New design does not increase usage.
# H1 : New design increases usage.

# %%
# Q4

new = 520
old = 480

print("New Button Clicks =", new)
print("Old Button Clicks =", old)

if new > old:
    print("New button got more clicks.")
else:
    print("Old button got more clicks.")

print("If p-value is less than 0.05, reject H0.")
print("Otherwise accept H0.")
# Out:
# New Button Clicks = 520
# Old Button Clicks = 480
# New button got more clicks.
# If p-value is less than 0.05, reject H0.
# Otherwise accept H0.
